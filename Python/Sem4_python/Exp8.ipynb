# %%
import math
print(math.sqrt(16))
# Import only the sqrt function from the math package
from math import sqrt
print(sqrt(25))

# %%
import numpy as np
a = np.arange(6)
a
b = np.array([(1.5, 2, 3), (4, 5, 6)])
print(b)
c = np.array([(1.5, 2, 3), (4, 5, 6)], dtype=complex)
c
a = np.arange(15).reshape(3, 5)
a
a.shape()
a.ndim()
a.dtype.name
a.size()
type(a)

# %%
a = np.array([20,30,40,50])
print(a)
b = np.arange(4)
print(b)
c=a-b
print(c)
30, 40, 50])

# %%
a = np.array([[-1, 2, 0, 4],
[4, -0.5, 6, 0],
[2.6, 0, 7, 8],
[3, -7, 4, 2.0]])
a = a[:2, ::2]
print ("first 2 rows and alternate columns(0 and 2):\n", a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_715/1136677002.py in <cell line: 0>()
# ----> 1 a = np.array([[-1, 2, 0, 4],
#       2 [4, -0.5, 6, 0],
#       3 [2.6, 0, 7, 8],
#       4 [3, -7, 4, 2.0]])
#       5 a = a[:2, ::2]
#
# NameError: name 'np' is not defined
