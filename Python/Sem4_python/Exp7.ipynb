# %% [markdown]
# There are two types of TYPE CONVERSION in Python:
#
# Implicit Type Conversion :the Python interpreter automatically converts one data type to another without any user involvement.
#
# Explicit Type Conversion :the data type is manually changed by the user as per their requirement.

# %%
x = 5
print("x is of type:",type(x))
y = 3.4
print("y is of type:",type(y))
x = x + y
print(x)
print("x is of type:",type(x))
# Out:
# x is of type: <class 'int'>
# y is of type: <class 'float'>
# 8.4
# x is of type: <class 'float'>

# %%
# initializing string
s = "1010"
# printing string converting to float
e = float(s)
print ("After converting to float : ", end="")
print (e)
# printing string converting to int base 2
c = int(s,2)
print ("After converting to integer base 2 : ", end="")
print (c)
s="a"
c = ord(s)
print ("After converting character to integer : ",end="")
print (c)
# Convert ASCII value to characters
a = chr(99)
b = chr(67)
print(a)
print(b)
# printing integer converting to hexadecimal string
c = hex(10)
print ("After converting 10 to hexadecimal string : ",end="")
print (c)
# printing integer converting to octal string
c = oct(10)
print ("After converting 10 to octal string : ",end="")
print (c)
# Out:
# After converting to float : 1010.0
# After converting to integer base 2 : 10
# After converting character to integer : 97
# c
# C
# After converting 10 to hexadecimal string : 0xa
# After converting 10 to octal string : 0o12

# %%
s = 'mit'
# printing string converting to tuple
c = tuple(s)
print ("After converting string to tuple : ",end="")
print (c)
# printing string converting to set
c = set(s)
print ("After converting string to set : ",end="")
print (c)
# printing string converting to list
c = list(s)
print ("After converting string to list : ",end="")
print (c)
# Out:
# After converting string to tuple : ('m', 'i', 't')
# After converting string to set : {'i', 't', 'm'}
# After converting string to list : ['m', 'i', 't']

# %%
#string functions
var = 'PYTHON INTERPRETER'
print (var.capitalize())
var = 'MitPolytechnic'
print (var.lower())
print (var.upper())
print (var.swapcase())
var = 'welcome to Python programming'
print (var.title())
var='Python'
print (var.islower())
var='PYTHON'
print (var.isupper())
print ('2'.isdigit())
#find(str [,i [,j]])
var="Mit Polytechnic"
str="oly"
print ("\n",var.find(str)) # Finds the starting position of str
var="Mit Polytechnic"
str="Poly"
print (var.find(str,3,9)) #Finds the string between position 3 to 9
var='That is a good example'
str='was'
print ("\n",var.replace('is',str))
var = "This is a good example"
print ("\n",var.split())
var='Print new line\nNextline\nMove again to new line'
print (var.splitlines())
seq=('ab','bc','cd')
str='+'
print (str.join(seq),"\n")
# Out:
# Python interpreter
# mitpolytechnic
# MITPOLYTECHNIC
# mITpOLYTECHNIC
# Welcome To Python Programming
# False
# True
# True
#
#  5
# 4
#
#  That was a good example
#
#  ['This', 'is', 'a', 'good', 'example']
# ['Print new line', 'Nextline', 'Move again to new line']
# ab+bc+cd

# %% [markdown]
# MATHEMATICAL FUNCTIONS
#
# math.sqrt() Returns the square root of a number
#
# math.pow() Returns the value of x to the power of y
#
# math.gcd() Returns the greatest common divisor of two integers
#
# math.floor() Rounds a number down to the nearest integer
#
# math.ceil() Rounds a number up to the nearest integer
#
# math.factorial() Returns the factorial of a number

# %%
# Python code to demonstrate the working of
# ceil() and floor()
# importing "math" for mathematical operations
import math
from math import factorial,gcd
a = 2.3
print ("The ceil of 2.3 is : ", end="")
print (math.ceil(a))
print ("The floor of 2.3 is : ", end="")
print (math.floor(a))
a=5
b=2
print ("The power of 5 to 2 is : ", end="")
print (math.pow(a,b))
a=5
print ("The factorial of 5 is : ", end="")
print (math.factorial(a))
a=5
b=15
print ("The gcd of 5 and 15 is : ", end="")
print (math.gcd(5,15))
# Out:
# The ceil of 2.3 is : 3
# The floor of 2.3 is : 2
# The power of 5 to 2 is : 25.0
# The factorial of 5 is : 120
# The gcd of 5 and 15 is : 5

# %%
from math import sqrt, factorial
print(sqrt(16))
print(factorial(6))
# Out:
# 4.0
# 720

# %%
import random
print("\n",random.randint(1, 10))
print(random.random())
# Out:
#  10
# 0.23967308724643976

# %% [markdown]
# User Defined functions
#
# You can call a function by using the following types of arguments:-
#
# Required
#
# Keyword
#
# Default
#
# Variable-length

# %%
#Required Arguments
def printme(str):
#This prints a passed string
    print(str)
    return;
printme("MIT")
# Out:
# MIT

# %%
def printme( name ):
    "This prints a passed string into this function"
    print("Hello, " + name + " Good morning!\n")
    return;
printme('MIT')
# Out:
# Hello, MIT Good morning!

# %%
def printme( name ):
    "This prints a passed string into this function"
    print("Hello, " + name + " Good morning!\n")
    return;
printme('MIT')
# Out:
# Hello, MIT Good morning!

# %%
#DEFAULT ARGUMENTS
def printinfo( name, location='kothrud\n' ):
    "This prints a passed info into this function"
    print("Name: ", name)
    print("Location:", location)
    return;
# Now you can call printinfo function
printinfo( location='karveroad\n', name="SNDT" )
printinfo(name="MIT" )
# Out:
# Name:  SNDT
# Location: karveroad
#
# Name:  MIT
# Location: kothrud

# %%
#VARIABLE LENGTH ARGUMENTS
def printinfo( arg1, *n ):
    "This prints a variable passed arguments"
    print( "Output is: " ,arg1 )
    for i in n:
        print (i )
    return;
# Now you can call printinfo function
printinfo( 10 )
printinfo( 70, 60, 50,40,30 )
# Out:
# Output is:  10
# Output is:  70
# 60
# 50
# 40
# 30

# %%
#SCOPE OF VARIABLES
def my_func():
    x = 10
    print("\nValue inside/LOCAL function:",x)
my_func()
x = 20
print("Value outside/GLOBAL function:",x)
# Out:
# Value inside/LOCAL function: 10
# Value outside/GLOBAL function: 20

# %%
#LAMBDA FUNCTION
sum = lambda arg1, arg2: arg1 + arg2;
# Now you can call sum as a function
print ("\nValue of total : ", sum( 10, 20 ))
print ("Value of total : ", sum( 20, 20 ))
# Out:
# Value of total :  30
# Value of total :  40

# %% [markdown]
# **Python’s argument passing model : “Pass by Value” and “Pass by Reference”
#
# PASS BY VALUE HAS DIFFERENT MEMORY LOCATIONS FOR ACTUAL AND FORMAL PARAMETERS
#
# PASS BY REFERENCE HAS SAME MEMORY LOCATIONS FOR BOTH ACTUAL AND FORMAL PARAMETERS.
#
# In languages like C we always pass by Value.
#
# If you want to Pass by Reference you need to use pointer ,you need to pass an address and receive address into a pointer.
#
# In Java you only have pass by value for primitive types.For objects you have only pass by reference.
#
# In python it depends on passing the MUTABLE OR IMMUTABLE OBJECT.
#
# If MUTABLE OBJECT IS PASSED then from formal parameters
# we can modify the the object i.e.actual parameters.
#
# If IMMUTABLE OBJECT IS PASSED then from formal parameters we get new object and the actual parameter is not affected.

# %%
def zero(n): #here n is formal parameter set to 0
    print(id(n)) #address of n
    n=0
    print(id(n))
a=100 # a is actual parameter
print(id(a)) #address of a
zero(a) # we are passing parameter a to n
print(a) # a is initially 100.After calling function with a ,where you are setting formal parameter to 0 ,what is valu
# Out:
# 11648520
# 11648520
# 11645320
# 100

# %%
def add(lst): #lst=1,2,3,0 l=1,2,3,0 5840
    print(id(lst))
    lst.append(0)
    print(id(lst))
l=[1,2,3]
print(id(l))
add(l)
print(l)
# Out:
# 132544685126848
# 132544685126848
# 132544685126848
# [1, 2, 3, 0]

# %%
def changeme( mylist1 ):
    print(id(mylist1))
    mylist1= [1,2,3,4] # This would assig new reference in mylist
    print(id(mylist1))
    print ("Values inside the function: ", mylist1)
    return;
# Now you can call changeme function
mylist = [10,20,30]
print(id(mylist))
changeme( mylist )
print ("Values outside the function: ", mylist)
# Out:
# 132544685123584
# 132544685123584
# 132544685127168
# Values inside the function:  [1, 2, 3, 4]
# Values outside the function:  [10, 20, 30]

# %% [markdown]
# Write Python function that accepts a string and calculates the number of uppercase and lowercase letters.

# %%
def check_string(my_string):
    upper_case_count = 0
    lower_case_count = 0
    for count in my_string:
        if count.isupper():
            upper_case_count += 1
        elif count.islower():
            lower_case_count += 1
        else:
            pass # Do nothing
    print("\nString : ", my_string)
    print("\nUppercase characters : ", upper_case_count)
    print("\nLowercase characters : ", lower_case_count)
user_input = input("Enter string to test : ")
check_string(user_input)
# Out:
# Enter string to test : mit
#
# String :  mit
#
# Uppercase characters :  0
#
# Lowercase characters :  3

# %% [markdown]
# Write a Python FUNCTION program to generate a random float where the value is between 5 and 50 using Python Module.

# %%
import random
def generate_random_number(low, high):
    print("\nRandom float value between " + low + " and " + high +" : ", random.uniform(float(low), float(high)))
    print(random.randint(int(low),int(high)))
    print("Print random values between 0 and 1",random.random())
my_low = input("\nEnter lower range value : ")
my_high = input("\nEnter higher range value : ")
generate_random_number(my_low, my_high)
# Out:
# Enter lower range value : 1
#
# Enter higher range value : 5
#
# Random float value between 1 and 5 :  1.9516550501494425
# 2
# Print random values between 0 and 1 0.7689670398019895

# %%
def myfunc(text, num):
    while num > 0:
        print(text)
        num = num - 1
myfunc('Hello', 4)
# Out:
# Hello
# Hello
# Hello
# Hello

# %%
num = 3
def func():
    num = 1
    print(num)
func()
print(num)
# Out:
# 1
# 3

# %%
import math
print(math.sqrt(16))
from math import sqrt
print(sqrt(16))
import math as m
print(m.sqrt(16))
# Out:
# 4.0
# 4.0
# 4.0

# %%
import sys
sys.path # This is an environment variable that is a search path for all Python modules
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/usr/local/lib/python3.12/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.12/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
import sys
sys.version #This attribute displays a string containing the version number of the current Python interpreter.
# Out:
# '3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]'

# %%
# %%writefile module1.py
def check_prime(num):
    if num ==1:
        print(" prime no")
        return
    if num==2 or num==3:
        print("prime no")
        return
    if num%2==0 or num%3==0:
        print("Not prime")
        return
    count=5
    for count in range(5,num,count+6):
        if (num % count) == 0 or ((num) % count+2==0):
            print("Not prime")
            return
    print("prime no")
def calculate_factorial(num):
    fact = 1
    if num > 0:
        for count in range(1, num + 1):
            fact *= count
        print("\nFactorial of ", num, " is", fact)
    elif num == 0:
        print("\nFactorial of 0 is 1")
    else:
        print("\nPlease enter a non-negative integer !")
# Out:
# Writing module1.py

# %%
# %%writefile module2.py
def add(a, b):
    result = a + b
    return result
def sub(a, b):
    result = a - b
    return result
def mul(a, b):
    result = a * b
    return result
def div(a, b):
    result = a / b
    return result
# Out:
# Writing module2.py

# %%
import module1 as m
number = int(input("\nEnter number = "))
print(m.check_prime(number))
print(m.calculate_factorial(number))
# Out:
# Enter number = 23
# prime no
# None
#
# Factorial of  23  is 25852016738884976640000
# None

# %%
import module2 as m1
a, b = map(int, input("Enter two numbers separated by a space: ").split())
print(m1.add(a,b))
print(m1.mul(a,b))
# Out:
# Enter two numbers separated by a space: 12 12
# 24
# 144
